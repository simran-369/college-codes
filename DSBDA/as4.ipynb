# %%
import pandas as pd

# %%
data= pd.read_csv('fb.csv')

# %%
print(type(data))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data.shape
# Out:
# (500, 19)

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.tail()
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 495   0.0                       4684                             7536
# 496   0.0                       3480                             6229
# 497   0.0                       3778                             7216
# 498   0.0                       4156                             7564
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
print(type(data['Category']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
data.iloc[2:9,:]
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
# 5            139441  Status         2          12             1          9
# 6            139441   Photo         3          12             1          3
# 7            139441   Photo         3          12             7          9
# 8            139441  Status         2          12             7          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
# 5   0.0                      10472                            20849
# ...

# %%
data.iloc[2:10,1:5]
# Out:
#      Type  Category  Post Month  Post Weekday
# 2   Photo         3          12             3
# 3   Photo         2          12             2
# 4   Photo         2          12             2
# 5  Status         2          12             1
# 6   Photo         3          12             1
# 7   Photo         3          12             7
# 8  Status         2          12             7
# 9   Photo         3          12             6

# %%
x=data.iloc[2:10,1:5]

# %%
x.shape
# Out:
# (8, 4)

# %%
data.iloc[10,:]
# Out:
# Page total likes                                                       139441
# Type                                                                   Status
# Category                                                                    2
# Post Month                                                                 12
# Post Weekday                                                                5
# Post Hour                                                                  10
# Paid                                                                      0.0
# Lifetime Post Total Reach                                               21744
# Lifetime Post Total Impressions                                         42334
# Lifetime Engaged Users                                                   4258
# Lifetime Post Consumers                                                  4100
# Lifetime Post Consumptions                                               4540
# ...

# %%
data.iloc[12:20,18]
# Out:
# 12    104
# 13    152
# 14    599
# 15    108
# 16     54
# 17    713
# 18     75
# 19     42
# Name: Total Interactions, dtype: int64

# %%
data.iloc[12:20,[2,5,11,13]]
# Out:
#     Category  Post Hour  Lifetime Post Consumptions  \
# 12         2         10                         133
# 13         2          3                         168
# 14         2          5                         417
# 15         2         10                        1425
# 16         3          3                         148
# 17         1         12                        1655
# 18         3          3                         112
# 19         3         11                         111
#
#     Lifetime Post reach by people who like your Page
# 12                                              2072
# 13                                              1917
# 14                                             19312
# 15                                              8548
# 16                                              1050
# 17                                             39776
# 18                                              2410
# 19                                              1161

# %%
data.iloc[[1,2,7,12],[2,5,11,13]]
# Out:
#     Category  Post Hour  Lifetime Post Consumptions  \
# 1          2         10                        1674
# 2          3          3                         154
# 7          3          9                         305
# 12         2         10                         133
#
#     Lifetime Post reach by people who like your Page
# 1                                               6112
# 2                                               1503
# 7                                              11056
# 12                                              2072

# %%
data.iloc[:,:-12]
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
#      Paid
# 0     0.0
# 1     0.0
# ...

# %%
data.loc[:,'Type']
# Out:
# 0       Photo
# 1      Status
# 2       Photo
# 3       Photo
# 4       Photo
#         ...
# 495     Photo
# 496     Photo
# 497     Photo
# 498     Photo
# 499     Photo
# Name: Type, Length: 500, dtype: object

# %%
data.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
x=[]
x.extend(range(2,20))
x.extend(range(50,70))

# %%
data.iloc[x,2:6]
# Out:
#     Category  Post Month  Post Weekday  Post Hour
# 2          3          12             3          3
# 3          2          12             2         10
# 4          2          12             2          3
# 5          2          12             1          9
# 6          3          12             1          3
# 7          3          12             7          9
# 8          2          12             7          3
# 9          3          12             6         10
# 10         2          12             5         10
# 11         2          12             5         10
# 12         2          12             5         10
# 13         2          12             5          3
# 14         2          12             4          5
# 15         2          12             3         10
# 16         3          12             3          3
# 17         1          12             2         12
# 18         3          12             2          3
# 19         3          12             1         11
# ...

# %%
X=data[['Type','Category','comment','like']]

# %%
X.shape
# Out:
# (500, 4)

# %%
X.head()
# Out:
#      Type  Category  comment    like
# 0   Photo         2        4    79.0
# 1  Status         2        5   130.0
# 2   Photo         3        0    66.0
# 3   Photo         2       58  1572.0
# 4   Photo         2       19   325.0

# %%
Y=X[X['like']>100]

# %%
Y.shape
# Out:
# (252, 4)

# %%
Y.head()
# Out:
#      Type  Category  comment    like
# 1  Status         2        5   130.0
# 3   Photo         2       58  1572.0
# 4   Photo         2       19   325.0
# 5  Status         2        1   152.0
# 6   Photo         3        3   249.0

# %%
Z=X[(X['like']>100) & (X['comment']>5)]

# %%
Z.shape
# Out:
# (139, 4)

# %%
Z.head()
# Out:
#       Type  Category  comment    like
# 3    Photo         2       58  1572.0
# 4    Photo         2       19   325.0
# 17   Photo         1       15   678.0
# 26  Status         2       10   412.0
# 28   Photo         2       36   523.0

# %%
Z.to_csv('output1.csv',index=False)

# %%
nd=pd.read_csv('newfb.csv')

# %%
nd.shape
# Out:
# (134, 19)

# %%
data.shape
# Out:
# (500, 19)

# %%
merged = pd.concat([data, nd], ignore_index=True)

# %%
merged.shape
# Out:
# (634, 19)

# %%
P=data.drop(['Type','comment','Category'],axis=1)

# %%
P.shape
# Out:
# (500, 16)

# %%
Q=data.drop([1,3,4,5,6,7,8])

# %%
Q.shape
# Out:
# (493, 19)

# %%
Y=Z.sort_values(by='comment',ascending=False)

# %%
Y.head()
# Out:
#       Type  Category  comment    like
# 244  Photo         2      372  5172.0
# 460  Photo         3      146  1546.0
# 168  Photo         1      144  1622.0
# 288  Photo         1      103   469.0
# 228  Photo         2       64   367.0

# %%
Z.shape
# Out:
# (139, 4)

# %%
y=Z.T

# %%
y.shape
# Out:
# (4, 139)

# %%
Z.shape
# Out:
# (139, 4)

# %%
Z.melt()
# Out:
#     variable   value
# 0       Type   Photo
# 1       Type   Photo
# 2       Type   Photo
# 3       Type  Status
# 4       Type   Photo
# ..       ...     ...
# 551     like   579.0
# 552     like   360.0
# 553     like   277.0
# 554     like   185.0
# 555     like   125.0
#
# [556 rows x 2 columns]

# %%
Z.shape
# Out:
# (139, 4)

# %%
Z.columns
# Out:
# Index(['Type', 'Category', 'comment', 'like'], dtype='object')

# %%
Z.head()
# Out:
#       Type  Category  comment    like
# 3    Photo         2       58  1572.0
# 4    Photo         2       19   325.0
# 17   Photo         1       15   678.0
# 26  Status         2       10   412.0
# 28   Photo         2       36   523.0

# %%
Z.melt(id_vars='Category')
# Out:
#      Category variable   value
# 0           2     Type   Photo
# 1           2     Type   Photo
# 2           1     Type   Photo
# 3           2     Type  Status
# 4           2     Type   Photo
# ..        ...      ...     ...
# 412         1     like   579.0
# 413         2     like   360.0
# 414         3     like   277.0
# 415         3     like   185.0
# 416         3     like   125.0
#
# [417 rows x 3 columns]

# %%
w=pd.get_dummies(Z)

# %%
w.head()
# Out:
#     Category  comment    like  Type_Link  Type_Photo  Type_Status  Type_Video
# 3          2       58  1572.0      False        True        False       False
# 4          2       19   325.0      False        True        False       False
# 17         1       15   678.0      False        True        False       False
# 26         2       10   412.0      False       False         True       False
# 28         2       36   523.0      False        True        False       False
